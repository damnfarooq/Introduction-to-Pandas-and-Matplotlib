# %% [markdown]
# # <h1 align='center' >Computer Application in Engineering Design Lab</h1>
# <h2 align='center' >Lab 13, BCE Fall 2021</h2>
# <h3 align='left' >Instructor: Muhammad Farooq Khan</h3>
# <h4>Date: 20-Dec-2021</h4>

# %% [markdown]
# ### Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("prostate.csv")
df
# Out:
#     Unnamed: 0    lcavol   lweight  age      lbph  svi       lcp  gleason  \
# 0            1 -0.579818  2.769459   50 -1.386294    0 -1.386294        6
# 1            2 -0.994252  3.319626   58 -1.386294    0 -1.386294        6
# 2            3 -0.510826  2.691243   74 -1.386294    0 -1.386294        7
# 3            4 -1.203973  3.282789   58 -1.386294    0 -1.386294        6
# 4            5  0.751416  3.432373   62 -1.386294    0 -1.386294        6
# ..         ...       ...       ...  ...       ...  ...       ...      ...
# 92          93  2.830268  3.876396   68 -1.386294    1  1.321756        7
# 93          94  3.821004  3.896909   44 -1.386294    1  2.169054        7
# 94          95  2.907447  3.396185   52 -1.386294    1  2.463853        7
# 95          96  2.882564  3.773910   68  1.558145    1  1.558145        7
# 96          97  3.471966  3.974998   68  0.438255    1  2.904165        7
#
#     pgg45      lpsa
# 0       0 -0.430783
# 1       0 -0.162519
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0    lcavol   lweight  age      lbph  svi       lcp  gleason  \
# 0           1 -0.579818  2.769459   50 -1.386294    0 -1.386294        6
# 1           2 -0.994252  3.319626   58 -1.386294    0 -1.386294        6
# 2           3 -0.510826  2.691243   74 -1.386294    0 -1.386294        7
#
#    pgg45      lpsa
# 0      0 -0.430783
# 1      0 -0.162519
# 2     20 -0.162519

# %%
df.tail(3)
# Out:
#     Unnamed: 0    lcavol   lweight  age      lbph  svi       lcp  gleason  \
# 94          95  2.907447  3.396185   52 -1.386294    1  2.463853        7
# 95          96  2.882564  3.773910   68  1.558145    1  1.558145        7
# 96          97  3.471966  3.974998   68  0.438255    1  2.904165        7
#
#     pgg45      lpsa
# 94     10  5.143124
# 95     80  5.477509
# 96     20  5.582932

# %%
df.index
# Out:
# RangeIndex(start=0, stop=97, step=1)

# %%
x = df.to_numpy()  # convert pandas to numpy    
print(x)
# Out:
# [[ 1.00000000e+00 -5.79818495e-01  2.76945883e+00  5.00000000e+01
#   -1.38629436e+00  0.00000000e+00 -1.38629436e+00  6.00000000e+00
#    0.00000000e+00 -4.30782916e-01]
#  [ 2.00000000e+00 -9.94252273e-01  3.31962573e+00  5.80000000e+01
#   -1.38629436e+00  0.00000000e+00 -1.38629436e+00  6.00000000e+00
#    0.00000000e+00 -1.62518929e-01]
#  [ 3.00000000e+00 -5.10825624e-01  2.69124308e+00  7.40000000e+01
#   -1.38629436e+00  0.00000000e+00 -1.38629436e+00  7.00000000e+00
#    2.00000000e+01 -1.62518929e-01]
#  [ 4.00000000e+00 -1.20397280e+00  3.28278915e+00  5.80000000e+01
#   -1.38629436e+00  0.00000000e+00 -1.38629436e+00  6.00000000e+00
#    0.00000000e+00 -1.62518929e-01]
#  [ 5.00000000e+00  7.51416089e-01  3.43237300e+00  6.20000000e+01
#   -1.38629436e+00  0.00000000e+00 -1.38629436e+00  6.00000000e+00
#    0.00000000e+00  3.71563556e-01]
#  [ 6.00000000e+00 -1.04982212e+00  3.22882616e+00  5.00000000e+01
# ...

# %%
# notice the values in exponential

import numpy as np
np.set_printoptions(suppress=True)

# use this at top of the code to get nice values in numpy

# %%
x = df.to_numpy()  # convert pandas to numpy    
print(x)
# Out:
# [[  1.          -0.5798185    2.76945883  50.          -1.38629436
#     0.          -1.38629436   6.           0.          -0.43078292]
#  [  2.          -0.99425227   3.31962573  58.          -1.38629436
#     0.          -1.38629436   6.           0.          -0.16251893]
#  [  3.          -0.51082562   2.69124308  74.          -1.38629436
#     0.          -1.38629436   7.          20.          -0.16251893]
#  [  4.          -1.2039728    3.28278915  58.          -1.38629436
#     0.          -1.38629436   6.           0.          -0.16251893]
#  [  5.           0.75141609   3.432373    62.          -1.38629436
#     0.          -1.38629436   6.           0.           0.37156356]
#  [  6.          -1.04982212   3.22882616  50.          -1.38629436
#     0.          -1.38629436   6.           0.           0.76546784]
#  [  7.           0.73716407   3.47351804  64.           0.61518564
#     0.          -1.38629436   6.           0.           0.76546784]
# ...

# %%
df.T
# Out:
#                    0          1          2          3          4          5   \
# Unnamed: 0   1.000000   2.000000   3.000000   4.000000   5.000000   6.000000
# lcavol      -0.579818  -0.994252  -0.510826  -1.203973   0.751416  -1.049822
# lweight      2.769459   3.319626   2.691243   3.282789   3.432373   3.228826
# age         50.000000  58.000000  74.000000  58.000000  62.000000  50.000000
# lbph        -1.386294  -1.386294  -1.386294  -1.386294  -1.386294  -1.386294
# svi          0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# lcp         -1.386294  -1.386294  -1.386294  -1.386294  -1.386294  -1.386294
# gleason      6.000000   6.000000   7.000000   6.000000   6.000000   6.000000
# pgg45        0.000000   0.000000  20.000000   0.000000   0.000000   0.000000
# lpsa        -0.430783  -0.162519  -0.162519  -0.162519   0.371564   0.765468
#
#                    6          7          8          9   ...         87  \
# ...

# %%
# shape of pandas

df.shape
# Out:
# (97, 10)

# %%
# shape of numpy array

x.shape
# Out:
# (97, 10)

# %%
df
# Out:
#     Unnamed: 0    lcavol   lweight  age      lbph  svi       lcp  gleason  \
# 0            1 -0.579818  2.769459   50 -1.386294    0 -1.386294        6
# 1            2 -0.994252  3.319626   58 -1.386294    0 -1.386294        6
# 2            3 -0.510826  2.691243   74 -1.386294    0 -1.386294        7
# 3            4 -1.203973  3.282789   58 -1.386294    0 -1.386294        6
# 4            5  0.751416  3.432373   62 -1.386294    0 -1.386294        6
# ..         ...       ...       ...  ...       ...  ...       ...      ...
# 92          93  2.830268  3.876396   68 -1.386294    1  1.321756        7
# 93          94  3.821004  3.896909   44 -1.386294    1  2.169054        7
# 94          95  2.907447  3.396185   52 -1.386294    1  2.463853        7
# 95          96  2.882564  3.773910   68  1.558145    1  1.558145        7
# 96          97  3.471966  3.974998   68  0.438255    1  2.904165        7
#
#     pgg45      lpsa
# 0       0 -0.430783
# 1       0 -0.162519
# ...

# %%
x0 = df["lcavol"]   # lcavol is the first column of dataset, check 
x0
# it is still pandas
# Out:
# 0    -0.579818
# 1    -0.994252
# 2    -0.510826
# 3    -1.203973
# 4     0.751416
#         ...
# 92    2.830268
# 93    3.821004
# 94    2.907447
# 95    2.882564
# 96    3.471966
# Name: lcavol, Length: 97, dtype: float64

# %%
in0 = x0.to_numpy()
print(in0)
in0.shape
# Out:
# [-0.5798185  -0.99425227 -0.51082562 -1.2039728   0.75141609 -1.04982212
#   0.73716407  0.69314718 -0.77652879  0.22314355  0.25464222 -1.34707365
#   1.61342993  1.47704872  1.20597081  1.54115907 -0.41551544  2.28848617
#  -0.56211892  0.18232156  1.14740245  2.05923883 -0.54472718  1.78170913
#   0.3852624   1.44691898  0.51282363 -0.40047757  1.04027671  2.40964417
#   0.28517894  0.18232156  1.2753628   0.00995033 -0.01005034  1.30833282
#   1.42310833  0.45742485  2.66095859  0.7975072   0.62057649  1.44220199
#   0.58221562  1.77155676  1.4861397   1.6639261   2.72785283  1.16315081
#   1.74571553  1.22082992  1.0919233   1.66013103  0.51282363  2.12704052
#   3.15359036  1.2669476   0.97455964  0.46373402  0.54232429  1.0612565
#   0.45742485  1.99741771  2.77570885  2.03470565  2.07317193  1.45861502
#   2.02287119  2.19833507 -0.4462871   1.19392247  1.86408013  1.16002092
#   1.21491274  1.83896107  2.99922616  3.14113048  2.010895    2.53765722
# ...

# %%
in0 = in0.reshape(in0.shape[0],1)

# %%
in0.shape
# Out:
# (97, 1)

# %%
# similarly we can seperate out any column as a numpy array
# then remember how to stack? tb to lab 12

# %%
# slice out many columns together from pandas dataframe
# lets load the data again

# %%
df = pd.read_csv("prostate.csv")
df
# Out:
#     Unnamed: 0    lcavol   lweight  age      lbph  svi       lcp  gleason  \
# 0            1 -0.579818  2.769459   50 -1.386294    0 -1.386294        6
# 1            2 -0.994252  3.319626   58 -1.386294    0 -1.386294        6
# 2            3 -0.510826  2.691243   74 -1.386294    0 -1.386294        7
# 3            4 -1.203973  3.282789   58 -1.386294    0 -1.386294        6
# 4            5  0.751416  3.432373   62 -1.386294    0 -1.386294        6
# ..         ...       ...       ...  ...       ...  ...       ...      ...
# 92          93  2.830268  3.876396   68 -1.386294    1  1.321756        7
# 93          94  3.821004  3.896909   44 -1.386294    1  2.169054        7
# 94          95  2.907447  3.396185   52 -1.386294    1  2.463853        7
# 95          96  2.882564  3.773910   68  1.558145    1  1.558145        7
# 96          97  3.471966  3.974998   68  0.438255    1  2.904165        7
#
#     pgg45      lpsa
# 0       0 -0.430783
# 1       0 -0.162519
# ...

# %%
df = np.array(df) #pandas data frame to numpy
x = df [::,1:9]
y = df [::,9:10]
print(x.shape)
print(y.shape)
# Out:
# (97, 8)
# (97, 1)

# %%
print(x)
# Out:
# [[ -0.5798185    2.76945883  50.          -1.38629436   0.
#    -1.38629436   6.           0.        ]
#  [ -0.99425227   3.31962573  58.          -1.38629436   0.
#    -1.38629436   6.           0.        ]
#  [ -0.51082562   2.69124308  74.          -1.38629436   0.
#    -1.38629436   7.          20.        ]
#  [ -1.2039728    3.28278915  58.          -1.38629436   0.
#    -1.38629436   6.           0.        ]
#  [  0.75141609   3.432373    62.          -1.38629436   0.
#    -1.38629436   6.           0.        ]
#  [ -1.04982212   3.22882616  50.          -1.38629436   0.
#    -1.38629436   6.           0.        ]
#  [  0.73716407   3.47351804  64.           0.61518564   0.
#    -1.38629436   6.           0.        ]
#  [  0.69314718   3.539509    58.           1.53686722   0.
#    -1.38629436   6.           0.        ]
#  [ -0.77652879   3.539509    47.          -1.38629436   0.
#    -1.38629436   6.           0.        ]
# ...

# %%
print(y)
# Out:
# [[-0.43078292]
#  [-0.16251893]
#  [-0.16251893]
#  [-0.16251893]
#  [ 0.37156356]
#  [ 0.76546784]
#  [ 0.76546784]
#  [ 0.85441533]
#  [ 1.04731899]
#  [ 1.04731899]
#  [ 1.2669476 ]
#  [ 1.2669476 ]
#  [ 1.2669476 ]
#  [ 1.34807315]
#  [ 1.39871688]
#  [ 1.44691898]
#  [ 1.47017585]
#  [ 1.4929041 ]
#  [ 1.55814462]
#  [ 1.59938758]
#  [ 1.63899671]
#  [ 1.65822808]
#  [ 1.69561561]
#  [ 1.71379793]
#  [ 1.73165555]
#  [ 1.76644166]
#  [ 1.80005827]
#  [ 1.81645208]
#  [ 1.84845481]
#  [ 1.89461685]
#  [ 1.92424865]
#  [ 2.00821403]
#  [ 2.00821403]
#  [ 2.02154756]
#  [ 2.04769284]
#  [ 2.08567209]
#  [ 2.15755932]
#  [ 2.19165353]
#  [ 2.21375388]
#  [ 2.27726729]
#  [ 2.29757255]
#  [ 2.30757263]
#  [ 2.32727771]
#  [ 2.37490575]
#  [ 2.52172062]
#  [ 2.55334381]
#  [ 2.56878813]
#  [ 2.56878813]
#  [ 2.59151638]
#  [ 2.59151638]
#  [ 2.65675691]
#  [ 2.67759099]
#  [ 2.68444034]
#  [ 2.69124308]
#  [ 2.7047113 ]
#  [ 2.71800053]
#  [ 2.78809291]
#  [ 2.7942279 ]
# ...

# %% [markdown]
# ### Matplotlib

# %%
# Y value with respect to X

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("XY-Plot")
plt.show()

# %%
# Y value with respect to index

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Y")
plt.show()

# %%
# Y value with respect to index

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Y")
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
# subplots

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
# Scatter Plot

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
# Scatter Plot

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y, color = 'r', marker = 'x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()
